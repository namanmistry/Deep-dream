# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import inception_v3
import IPython.display
from PIL import Image
base_image_path = "dream.png"
result_prefix = "dream"

# These are the names of the layers
# for which we try to maximize activation,
# as well as their weight in the final loss
# we try to maximize.
# You can tweak these setting to obtain new visual effects.
layer_settings = {
    "mixed4": 2.0,
    "mixed5": 2.5,
    "mixed6": 3.0,
    "mixed7": 3.5,
}

# Playing with these hyperparameters will also allow you to achieve new effects
step = 0.01  # Gradient ascent step size
num_octave = 5  # Number of scales at which to run gradient ascent
octave_scale = 1.4  # Size ratio between scales
iterations = 60  # Number of ascent steps per scale
max_loss = 15.0

# %%
from IPython.display import Image, display

display(Image(base_image_path))

# %%
def preprocess_image(image_path):
    # Util function to open, resize and format pictures
    # into appropriate arrays.
    img = keras.preprocessing.image.load_img(image_path)
    img = keras.preprocessing.image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = inception_v3.preprocess_input(img)
    return img


def deprocess_image(x):
    # Util function to convert a NumPy array into a valid image.
    x = x.reshape((x.shape[1], x.shape[2], 3))
    # Undo inception v3 preprocessing
    x /= 2.0
    x += 0.5
    x *= 255.0
    # Convert to uint8 and clip to the valid range [0, 255]
    x = np.clip(x, 0, 255).astype("uint8")
    return x

# %%
# Build an InceptionV3 model loaded with pre-trained ImageNet weights
model = inception_v3.InceptionV3(weights="imagenet", include_top=False)

# Get the symbolic outputs of each "key" layer (we gave them unique names).
outputs_dict = dict(
    [
        (layer.name, layer.output)
        for layer in [model.get_layer(name) for name in layer_settings.keys()]
    ]
)

# Set up a model that returns the activation values for every target layer
# (as a dict)
feature_extractor = keras.Model(inputs=model.inputs, outputs=outputs_dict)

# %%
def compute_loss(img):
  # Pass forward the image through the model to retrieve the activations.
  # Converts the image into a batch of size 1.

  layer_activations = feature_extractor(img)
  layer_activations = layer_activations.values()
  if len(layer_activations) == 1:
    layer_activations = [layer_activations]

  losses = []
  for act in layer_activations:
    loss = tf.math.reduce_mean(act)
    losses.append(loss)

  return  tf.reduce_sum(losses)

# %%
@tf.function
def gradient_ascent_step(img, learning_rate):
    with tf.GradientTape() as tape:
        tape.watch(img)
        loss = compute_loss(img)
    # Compute gradients.
    grads = tape.gradient(loss, img)
    # Normalize gradients.
    grads /= tf.maximum(tf.reduce_mean(tf.abs(grads)), 1e-6)
    img += learning_rate * grads
    return loss, img


def gradient_ascent_loop(img, iterations, learning_rate, max_loss=None):
    for i in range(iterations):
        loss, img = gradient_ascent_step(img, learning_rate)
        if max_loss is not None and loss > max_loss:
            break
        print("... Loss value at step %d: %.2f" % (i, loss))
    return img

# %%
original_img = preprocess_image(base_image_path)
original_shape = original_img.shape[1:3]

successive_shapes = [original_shape]
for i in range(1, num_octave):
    shape = tuple([int(dim / (octave_scale ** i)) for dim in original_shape])
    successive_shapes.append(shape)
successive_shapes = successive_shapes[::-1]
shrunk_original_img = tf.image.resize(original_img, successive_shapes[0])

img = tf.identity(original_img)  # Make a copy
for i, shape in enumerate(successive_shapes):
    print("Processing octave %d with shape %s" % (i, shape))
    img = tf.image.resize(img, shape)
    img = gradient_ascent_loop(
        img, iterations=iterations, learning_rate=step, max_loss=max_loss
    )
    upscaled_shrunk_original_img = tf.image.resize(shrunk_original_img, shape)
    same_size_original = tf.image.resize(original_img, shape)
    lost_detail = same_size_original - upscaled_shrunk_original_img

    img += lost_detail
    shrunk_original_img = tf.image.resize(original_img, shape)
    

keras.preprocessing.image.save_img(result_prefix + ".png", deprocess_image(img.numpy()))
# Out:
# Processing octave 0 with shape (131, 233)
# ... Loss value at step 0: 1.09
# ... Loss value at step 1: 1.44
# ... Loss value at step 2: 1.63
# ... Loss value at step 3: 1.75
# ... Loss value at step 4: 1.83
# ... Loss value at step 5: 1.90
# ... Loss value at step 6: 1.97
# ... Loss value at step 7: 2.03
# ... Loss value at step 8: 2.08
# ... Loss value at step 9: 2.12
# ... Loss value at step 10: 2.16
# ... Loss value at step 11: 2.20
# ... Loss value at step 12: 2.23
# ... Loss value at step 13: 2.26
# ... Loss value at step 14: 2.27
# ... Loss value at step 15: 2.29
# ... Loss value at step 16: 2.32
# ... Loss value at step 17: 2.34
# ... Loss value at step 18: 2.37
# ... Loss value at step 19: 2.38
# ... Loss value at step 20: 2.40
# ... Loss value at step 21: 2.41
# ... Loss value at step 22: 2.43
# ... Loss value at step 23: 2.43
# ... Loss value at step 24: 2.45
# ... Loss value at step 25: 2.46
# ... Loss value at step 26: 2.49
# ... Loss value at step 27: 2.49
# ... Loss value at step 28: 2.51
# ... Loss value at step 29: 2.52
# ... Loss value at step 30: 2.53
# ... Loss value at step 31: 2.54
# ... Loss value at step 32: 2.55
# ... Loss value at step 33: 2.55
# ... Loss value at step 34: 2.58
# ... Loss value at step 35: 2.59
# ... Loss value at step 36: 2.59
# ... Loss value at step 37: 2.61
# ... Loss value at step 38: 2.61
# ... Loss value at step 39: 2.62
# ... Loss value at step 40: 2.63
# ... Loss value at step 41: 2.64
# ... Loss value at step 42: 2.65
# ... Loss value at step 43: 2.67
# ... Loss value at step 44: 2.66
# ... Loss value at step 45: 2.69
# ... Loss value at step 46: 2.69
# ... Loss value at step 47: 2.70
# ... Loss value at step 48: 2.70
# ... Loss value at step 49: 2.71
# ... Loss value at step 50: 2.72
# ... Loss value at step 51: 2.72
# ... Loss value at step 52: 2.73
# ... Loss value at step 53: 2.73
# ... Loss value at step 54: 2.74
# ... Loss value at step 55: 2.75
# ... Loss value at step 56: 2.76
# ... Loss value at step 57: 2.76
# ... Loss value at step 58: 2.77
# ... Loss value at step 59: 2.77
# Processing octave 1 with shape (183, 326)
# ... Loss value at step 0: 0.96
# ... Loss value at step 1: 1.20
# ... Loss value at step 2: 1.37
# ... Loss value at step 3: 1.47
# ... Loss value at step 4: 1.54
# ... Loss value at step 5: 1.61
# ... Loss value at step 6: 1.67
# ... Loss value at step 7: 1.71
# ... Loss value at step 8: 1.76
# ... Loss value at step 9: 1.79
# ... Loss value at step 10: 1.84
# ... Loss value at step 11: 1.87
# ... Loss value at step 12: 1.91
# ... Loss value at step 13: 1.93
# ... Loss value at step 14: 1.96
# ... Loss value at step 15: 1.99
# ... Loss value at step 16: 2.01
# ... Loss value at step 17: 2.04
# ... Loss value at step 18: 2.06
# ... Loss value at step 19: 2.09
# ... Loss value at step 20: 2.10
# ... Loss value at step 21: 2.12
# ... Loss value at step 22: 2.13
# ... Loss value at step 23: 2.16
# ... Loss value at step 24: 2.18
# ... Loss value at step 25: 2.19
# ... Loss value at step 26: 2.21
# ... Loss value at step 27: 2.22
# ... Loss value at step 28: 2.24
# ... Loss value at step 29: 2.26
# ... Loss value at step 30: 2.26
# ... Loss value at step 31: 2.27
# ... Loss value at step 32: 2.29
# ... Loss value at step 33: 2.30
# ... Loss value at step 34: 2.32
# ... Loss value at step 35: 2.33
# ... Loss value at step 36: 2.34
# ... Loss value at step 37: 2.36
# ... Loss value at step 38: 2.36
# ... Loss value at step 39: 2.38
# ... Loss value at step 40: 2.38
# ... Loss value at step 41: 2.39
# ... Loss value at step 42: 2.40
# ... Loss value at step 43: 2.41
# ... Loss value at step 44: 2.42
# ... Loss value at step 45: 2.43
# ... Loss value at step 46: 2.44
# ... Loss value at step 47: 2.45
# ... Loss value at step 48: 2.46
# ... Loss value at step 49: 2.47
# ... Loss value at step 50: 2.48
# ... Loss value at step 51: 2.49
# ... Loss value at step 52: 2.50
# ... Loss value at step 53: 2.50
# ... Loss value at step 54: 2.51
# ... Loss value at step 55: 2.52
# ... Loss value at step 56: 2.52
# ... Loss value at step 57: 2.53
# ... Loss value at step 58: 2.54
# ... Loss value at step 59: 2.55
# Processing octave 2 with shape (257, 457)
# ... Loss value at step 0: 0.83
# ... Loss value at step 1: 1.05
# ... Loss value at step 2: 1.21
# ... Loss value at step 3: 1.32
# ... Loss value at step 4: 1.39
# ... Loss value at step 5: 1.45
# ... Loss value at step 6: 1.52
# ... Loss value at step 7: 1.57
# ... Loss value at step 8: 1.62
# ... Loss value at step 9: 1.66
# ... Loss value at step 10: 1.70
# ... Loss value at step 11: 1.73
# ... Loss value at step 12: 1.77
# ... Loss value at step 13: 1.79
# ... Loss value at step 14: 1.83
# ... Loss value at step 15: 1.85
# ... Loss value at step 16: 1.88
# ... Loss value at step 17: 1.91
# ... Loss value at step 18: 1.94
# ... Loss value at step 19: 1.95
# ... Loss value at step 20: 1.98
# ... Loss value at step 21: 2.00
# ... Loss value at step 22: 2.02
# ... Loss value at step 23: 2.04
# ... Loss value at step 24: 2.05
# ... Loss value at step 25: 2.07
# ... Loss value at step 26: 2.09
# ... Loss value at step 27: 2.11
# ... Loss value at step 28: 2.13
# ... Loss value at step 29: 2.14
# ... Loss value at step 30: 2.16
# ... Loss value at step 31: 2.17
# ... Loss value at step 32: 2.19
# ... Loss value at step 33: 2.20
# ... Loss value at step 34: 2.21
# ... Loss value at step 35: 2.23
# ... Loss value at step 36: 2.24
# ... Loss value at step 37: 2.25
# ... Loss value at step 38: 2.26
# ... Loss value at step 39: 2.28
# ... Loss value at step 40: 2.29
# ... Loss value at step 41: 2.30
# ... Loss value at step 42: 2.31
# ... Loss value at step 43: 2.33
# ... Loss value at step 44: 2.34
# ... Loss value at step 45: 2.35
# ... Loss value at step 46: 2.36
# ... Loss value at step 47: 2.37
# ... Loss value at step 48: 2.38
# ... Loss value at step 49: 2.39
# ... Loss value at step 50: 2.40
# ... Loss value at step 51: 2.40
# ... Loss value at step 52: 2.42
# ... Loss value at step 53: 2.41
# ... Loss value at step 54: 2.44
# ... Loss value at step 55: 2.44
# ... Loss value at step 56: 2.46
# ... Loss value at step 57: 2.47
# ... Loss value at step 58: 2.48
# ... Loss value at step 59: 2.49
# Processing octave 3 with shape (360, 640)
# ... Loss value at step 0: 0.85
# ... Loss value at step 1: 1.07
# ... Loss value at step 2: 1.25
# ... Loss value at step 3: 1.38
# ... Loss value at step 4: 1.47
# ... Loss value at step 5: 1.54
# ... Loss value at step 6: 1.60
# ... Loss value at step 7: 1.66
# ... Loss value at step 8: 1.71
# ... Loss value at step 9: 1.77
# ... Loss value at step 10: 1.80
# ... Loss value at step 11: 1.85
# ... Loss value at step 12: 1.88
# ... Loss value at step 13: 1.92
# ... Loss value at step 14: 1.94
# ... Loss value at step 15: 1.98
# ... Loss value at step 16: 2.01
# ... Loss value at step 17: 2.04
# ... Loss value at step 18: 2.06
# ... Loss value at step 19: 2.09
# ... Loss value at step 20: 2.11
# ... Loss value at step 21: 2.14
# ... Loss value at step 22: 2.16
# ... Loss value at step 23: 2.18
# ... Loss value at step 24: 2.20
# ... Loss value at step 25: 2.21
# ... Loss value at step 26: 2.23
# ... Loss value at step 27: 2.26
# ... Loss value at step 28: 2.27
# ... Loss value at step 29: 2.29
# ... Loss value at step 30: 2.31
# ... Loss value at step 31: 2.32
# ... Loss value at step 32: 2.34
# ... Loss value at step 33: 2.35
# ... Loss value at step 34: 2.37
# ... Loss value at step 35: 2.38
# ... Loss value at step 36: 2.40
# ... Loss value at step 37: 2.41
# ... Loss value at step 38: 2.43
# ... Loss value at step 39: 2.43
# ... Loss value at step 40: 2.45
# ... Loss value at step 41: 2.46
# ... Loss value at step 42: 2.48
# ... Loss value at step 43: 2.48
# ... Loss value at step 44: 2.50
# ... Loss value at step 45: 2.51
# ... Loss value at step 46: 2.52
# ... Loss value at step 47: 2.53
# ... Loss value at step 48: 2.55
# ... Loss value at step 49: 2.56
# ... Loss value at step 50: 2.57
# ... Loss value at step 51: 2.58
# ... Loss value at step 52: 2.59
# ... Loss value at step 53: 2.60
# ... Loss value at step 54: 2.61
# ... Loss value at step 55: 2.62
# ... Loss value at step 56: 2.63
# ... Loss value at step 57: 2.64
# ... Loss value at step 58: 2.64
# ... Loss value at step 59: 2.65
# Processing octave 4 with shape (504, 896)
# ... Loss value at step 0: 0.90
# ... Loss value at step 1: 1.12
# ... Loss value at step 2: 1.29
# ... Loss value at step 3: 1.42
# ... Loss value at step 4: 1.51
# ... Loss value at step 5: 1.59
# ... Loss value at step 6: 1.67
# ... Loss value at step 7: 1.73
# ... Loss value at step 8: 1.79
# ... Loss value at step 9: 1.84
# ... Loss value at step 10: 1.89
# ... Loss value at step 11: 1.93
# ... Loss value at step 12: 1.97
# ... Loss value at step 13: 2.01
# ... Loss value at step 14: 2.04
# ... Loss value at step 15: 2.08
# ... Loss value at step 16: 2.11
# ... Loss value at step 17: 2.14
# ... Loss value at step 18: 2.17
# ... Loss value at step 19: 2.19
# ... Loss value at step 20: 2.22
# ... Loss value at step 21: 2.24
# ... Loss value at step 22: 2.27
# ... Loss value at step 23: 2.29
# ... Loss value at step 24: 2.32
# ... Loss value at step 25: 2.34
# ... Loss value at step 26: 2.36
# ... Loss value at step 27: 2.38
# ... Loss value at step 28: 2.40
# ... Loss value at step 29: 2.42
# ... Loss value at step 30: 2.44
# ... Loss value at step 31: 2.45
# ... Loss value at step 32: 2.47
# ... Loss value at step 33: 2.49
# ... Loss value at step 34: 2.50
# ... Loss value at step 35: 2.51
# ... Loss value at step 36: 2.53
# ... Loss value at step 37: 2.54
# ... Loss value at step 38: 2.56
# ... Loss value at step 39: 2.57
# ... Loss value at step 40: 2.58
# ... Loss value at step 41: 2.60
# ... Loss value at step 42: 2.61
# ... Loss value at step 43: 2.63
# ... Loss value at step 44: 2.64
# ... Loss value at step 45: 2.66
# ... Loss value at step 46: 2.66
# ... Loss value at step 47: 2.68
# ... Loss value at step 48: 2.69
# ... Loss value at step 49: 2.70
# ... Loss value at step 50: 2.71
# ... Loss value at step 51: 2.73
# ... Loss value at step 52: 2.74
# ... Loss value at step 53: 2.75
# ... Loss value at step 54: 2.76
# ... Loss value at step 55: 2.78
# ... Loss value at step 56: 2.79
# ... Loss value at step 57: 2.80
# ... Loss value at step 58: 2.81
# ... Loss value at step 59: 2.82

# %%
deprocess_image
